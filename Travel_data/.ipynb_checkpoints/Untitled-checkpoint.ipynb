# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as linregress
import numpy as np

# %%
cta_bus_path = r"C:\Users\Kaleb\Chicago_Energy\Travel_data\CTA_Average_Bus_Ridership_1999_2020_1 (1).csv"
cta_rail_path = r"C:\Users\Kaleb\Chicago_Energy\Travel_data\CTA_Average_Rail_Station_Ridership_1999_2020_0 (1).csv"
metra_riders_path = r"C:\Users\Kaleb\Chicago_Energy\Travel_data\Metra_Monthly_Ridership_by_Line_2003_2020_0.csv"
yearly_data_path = r"C:\Users\Kaleb\Chicago_Energy\Travel_data\SYSTEMRIDERSHIP_0.csv"
census_data = r"C:\Users\Kaleb\Chicago_Energy\Data\Chicago_Population_Counts_2018.csv"

# %%
census_data_csv = pd.read_csv(census_data)
census_df = pd.DataFrame(census_data_csv)
census_df
census_df
# Out:
#    Geography Type  Year Geography COMMUNITY AREA NAME  Population - Total
# 0        Citywide  2018   Chicago             Chicago             2705988
# 1        ZIP Code  2018     60601            The Loop               14675
# 2        ZIP Code  2018     60602            The Loop                1244
# 3        ZIP Code  2018     60603            The Loop                1174
# 4        ZIP Code  2018     60604            The Loop                 782
# 5        ZIP Code  2018     60605            The Loop               27519
# 6        ZIP Code  2018     60606      Near West Side                3101
# 7        ZIP Code  2018     60607      Near West Side               29591
# 8        ZIP Code  2018     60608      Near West Side               79205
# 9        ZIP Code  2018     60609       Armour Square               61495
# 10       ZIP Code  2018     60610        Lincoln Park               39019
# 11       ZIP Code  2018     60611     Near North Side               32426
# 12       ZIP Code  2018     60612       Humboldt Park               34311
# 13       ZIP Code  2018     60613              Uptown               50113
# 14       ZIP Code  2018     60614        Lincoln Park               71308
# 15       ZIP Code  2018     60615     Grand Boulevard               41563
# 16       ZIP Code  2018     60616      Near West Side               54464
# 17       ZIP Code  2018     60617         Avalon Park               82534
# 18       ZIP Code  2018     60618      Lincoln Square               94395
# 19       ZIP Code  2018     60619         South Shore               61258
# 20       ZIP Code  2018     60620             Chatham               68096
# 21       ZIP Code  2018     60621     Washington Park               29042
# 22       ZIP Code  2018     60622        Logan Square               52793
# 23       ZIP Code  2018     60623      North Lawndale               85979
# 24       ZIP Code  2018     60624       Humboldt Park               36158
# 25       ZIP Code  2018     60625      Lincoln Square               79243
# 26       ZIP Code  2018     60626         Rogers Park               49730
# 27       ZIP Code  2018     60628            Roseland               66724
# 28       ZIP Code  2018     60629      Garfield Ridge              111850
# 29       ZIP Code  2018     60630        Norwood Park               57344
# 30       ZIP Code  2018     60631         Edison Park               29529
# 31       ZIP Code  2018     60632      South Lawndale               91039
# 32       ZIP Code  2018     60633             Pullman               12871
# 33       ZIP Code  2018     60634        Portage Park               75995
# 34       ZIP Code  2018     60636           Gage Park               32203
# 35       ZIP Code  2018     60637     Washington Park               47454
# 36       ZIP Code  2018     60638      Garfield Ridge               58797
# 37       ZIP Code  2018     60639      Belmont Cragin               90517
# 38       ZIP Code  2018     60640              Uptown               69715
# 39       ZIP Code  2018     60641         Albany Park               71023
# 40       ZIP Code  2018     60642        North Center               20201
# 41       ZIP Code  2018     60643        West Pullman               49870
# 42       ZIP Code  2018     60644              Austin               47712
# 43       ZIP Code  2018     60645         Rogers Park               47732
# 44       ZIP Code  2018     60646        Norwood Park               27987
# 45       ZIP Code  2018     60647        Logan Square               87509
# 46       ZIP Code  2018     60649            Woodlawn               46024
# 47       ZIP Code  2018     60651       Humboldt Park               63218
# 48       ZIP Code  2018     60652           West Lawn               43907
# 49       ZIP Code  2018     60653             Douglas               31972
# 50       ZIP Code  2018     60654     Near North Side               19135
# 51       ZIP Code  2018     60655             Beverly               28804
# 52       ZIP Code  2018     60656        Norwood Park               27579
# 53       ZIP Code  2018     60657            Lakeview               70052
# 54       ZIP Code  2018     60659          West Ridge               41068
# 55       ZIP Code  2018     60660         Rogers Park               43242
# 56       ZIP Code  2018     60661           West Town                9926
# 57       ZIP Code  2018     60666              O'Hare                   0
# 58       ZIP Code  2018     60707             Dunning               43019
# 59       ZIP Code  2018     60827        West Pullman               28577

# %%
cta_bus_csv = pd.read_csv(cta_bus_path)
cta_rail_csv = pd.read_csv(cta_rail_path)
metra_riders_csv = pd.read_csv(metra_riders_path)
yearly_data_csv = pd.read_csv(yearly_data_path)

# %%
cta_bus = pd.DataFrame(cta_bus_csv)
cta_bus = cta_bus.loc[cta_bus["YEAR"] == 2018]

cta_bus
# Out:
#      ROUTE  MONTH    YEAR DAY_TYPE_ID  AVG_RIDES
# 5003    79   12.0  2018.0          WK    22436.0
# 5004    66   12.0  2018.0          WK    19453.0
# 5005     4   12.0  2018.0          WK    18400.0
# 5006     8   12.0  2018.0          WK    18280.0
# 5007    77   12.0  2018.0          WK    17549.0
# ...    ...    ...     ...         ...        ...
# 8778  1001    1.0  2018.0          WK       62.0
# 8779  1001    1.0  2018.0         SAT       26.0
# 8780  1001    1.0  2018.0         SUN       21.0
# 8781   X98    1.0  2018.0          WK       11.0
# 8782   169    1.0  2018.0         SAT        4.0
#
# [3780 rows x 5 columns]

# %%
cta_bus_graph = plt.scatter(cta_bus["YEAR"], cta_bus["AVG_RIDES"])
plt.xlabel = ("Year")
plt.ylabel = ("Rides")
plt.title = ("Rides Per Year (CTA Bus Routes)")
cta_bus_graph

# %%
cta_rail = pd.DataFrame(cta_rail_csv)
cta_rail
# Out:
#                       NAME  RIDERSHIP_ID  YEAR  MONTH DAY_TYPE_ID  \
# 0                     18th           830  2020      1          WK
# 1                     18th           830  2020      1         SUN
# 2                     18th           830  2020      1         SAT
# 3       35-Bronzeville-IIT          1120  2020      1          WK
# 4       35-Bronzeville-IIT          1120  2020      1         SUN
# ...                    ...           ...   ...    ...         ...
# 111703  Western-Ravenswood          1480  1998     12         SUN
# 111704  Western-Ravenswood          1480  1998     12         SAT
# 111705              Wilson           540  1998     12          WK
# 111706              Wilson           540  1998     12         SUN
# 111707              Wilson           540  1998     12         SAT
#
#         TOTAL_RIDES  DAILY_AVG_RIDES
# 0           36372.0             1653
# 1            3193.0              638
# 2            3712.0              928
# 3           32031.0              727
# 4            2159.0              215
# ...             ...              ...
# 111703       3667.0              733
# 111704       6034.0             1508
# 111705      90844.0             4129
# 111706       8695.0             1739
# 111707      11064.0             2766
#
# [111708 rows x 7 columns]

# %%
metra_df = pd.DataFrame(metra_riders_csv)
metra_df
# Out:
#                                         NAME  YEAR  MONTH    RIDES  \
# 0               Burlington Northern Santa Fe  2020      1  1258782
# 1       Electric District Blue Island Branch  2020      1    21830
# 2                Electric District Main Line  2020      1   518139
# 3     Electric District South Chicago Branch  2020      1    41378
# 4                          Heritage Corridor  2020      1    63296
# ...                                      ...   ...    ...      ...
# 2829                    Rock Island District  2002     12   738686
# 2830                       SouthWest Service  2002     12   132724
# 2831                Union Pacific North Line  2002     12   640236
# 2832            Union Pacific Northwest Line  2002     12   717873
# 2833                 Union Pacific West Line  2002     12   519564
#
#       RIDERSHIP_ID
# 0               10
# 1                4
# 2                5
# 3                1
# 4                9
# ...            ...
# 2829             6
# 2830             8
# 2831            17
# 2832            13
# 2833            11
#
# [2834 rows x 5 columns]

# %%
cta_rail_df = cta_rail.loc[cta_rail["YEAR"] > 2014]
cta_bus_df = cta_bus.loc[cta_bus["YEAR"] > 2014]

# %%
cta_rail_df
# Out:
#                      NAME  RIDERSHIP_ID  YEAR  MONTH DAY_TYPE_ID  TOTAL_RIDES  \
# 0                    18th           830  2020      1          WK      36372.0
# 1                    18th           830  2020      1         SUN       3193.0
# 2                    18th           830  2020      1         SAT       3712.0
# 3      35-Bronzeville-IIT          1120  2020      1          WK      32031.0
# 4      35-Bronzeville-IIT          1120  2020      1         SUN       2159.0
# ...                   ...           ...   ...    ...         ...          ...
# 27550  Western-Ravenswood          1480  2015     12         SUN       8354.0
# 27551  Western-Ravenswood          1480  2015     12         SAT      10808.0
# 27552              Wilson           540  2015     12          WK     117877.0
# 27553              Wilson           540  2015     12         SUN      11727.0
# 27554              Wilson           540  2015     12         SAT      13968.0
#
#        DAILY_AVG_RIDES
# 0                 1653
# 1                  638
# 2                  928
# 3                  727
# 4                  215
# ...                ...
# 27550             1670
# 27551             2702
# 27552             2679
# 27553             1172
# 27554             1746
#
# [27555 rows x 7 columns]

# %%
cta_bus_df
cta_bus_graph = plt.bar(cta_bus_df["YEAR"], cta_bus_df["AVG_RIDES"])
plt.xlabel = "Year"
plt.ylabel = "Rides"
plt.title = "CTA Rides per Year"
cta_bus_graph
# Out:
# <BarContainer object of 3780 artists>

# %%
yearly_transit = pd.DataFrame(yearly_data_csv)
yearly_transit = yearly_transit.loc[yearly_transit["THEYEAR"] > 2014]
yearly_transit
# Out:
#     THEYEAR  CTA_BUS  CTA_RAIL  CTA_TOTAL  METRA  PACE  PACE_ADA
# 0      2019    237.3     218.5      455.8     74  28.5       4.1
# 7      2018    242.0     226.0      468.0     76  30.0       4.0
# 8      2017    249.0     230.0      479.0     79  31.0       4.0
# 27     2015    274.0     242.0      516.0     82  33.0       4.0
# 33     2016    259.0     239.0      498.0     80  31.0       4.0

# %%
new_cta_bus = cta_bus.rename(columns={"YEAR": "Year"})
new_cta_bus.astype(dtype="str")
travel_counts = pd.merge(new_cta_bus, census_df)
travel_counts
# Out:
#        ROUTE  MONTH    Year DAY_TYPE_ID  AVG_RIDES Geography Type Geography  \
# 0         79   12.0  2018.0          WK    22436.0       Citywide   Chicago
# 1         79   12.0  2018.0          WK    22436.0       ZIP Code     60601
# 2         79   12.0  2018.0          WK    22436.0       ZIP Code     60602
# 3         79   12.0  2018.0          WK    22436.0       ZIP Code     60603
# 4         79   12.0  2018.0          WK    22436.0       ZIP Code     60604
# ...      ...    ...     ...         ...        ...            ...       ...
# 226795   169    1.0  2018.0         SAT        4.0       ZIP Code     60660
# 226796   169    1.0  2018.0         SAT        4.0       ZIP Code     60661
# 226797   169    1.0  2018.0         SAT        4.0       ZIP Code     60666
# 226798   169    1.0  2018.0         SAT        4.0       ZIP Code     60707
# 226799   169    1.0  2018.0         SAT        4.0       ZIP Code     60827
#
#        COMMUNITY AREA NAME  Population - Total
# 0                  Chicago             2705988
# 1                 The Loop               14675
# 2                 The Loop                1244
# 3                 The Loop                1174
# 4                 The Loop                 782
# ...                    ...                 ...
# 226795         Rogers Park               43242
# 226796           West Town                9926
# 226797              O'Hare                   0
# 226798             Dunning               43019
# 226799        West Pullman               28577
#
# [226800 rows x 9 columns]

# %%
travel_counts = travel_counts.drop_duplicates(subset="ROUTE")
travel_counts
# Out:
#       ROUTE  MONTH    Year DAY_TYPE_ID  AVG_RIDES Geography Type Geography  \
# 0        79   12.0  2018.0          WK    22436.0       Citywide   Chicago
# 60       66   12.0  2018.0          WK    19453.0       Citywide   Chicago
# 120       4   12.0  2018.0          WK    18400.0       Citywide   Chicago
# 180       8   12.0  2018.0          WK    18280.0       Citywide   Chicago
# 240      77   12.0  2018.0          WK    17549.0       Citywide   Chicago
# ...     ...    ...     ...         ...        ...            ...       ...
# 18480   169   12.0  2018.0          WK      122.0       Citywide   Chicago
# 18720   X98   12.0  2018.0          WK        8.0       Citywide   Chicago
# 55860   130   10.0  2018.0          WK      182.0       Citywide   Chicago
# 73620    10    9.0  2018.0         SAT      475.0       Citywide   Chicago
# 91860   205    8.0  2018.0          WK      635.0       Citywide   Chicago
#
#       COMMUNITY AREA NAME  Population - Total
# 0                 Chicago             2705988
# 60                Chicago             2705988
# 120               Chicago             2705988
# 180               Chicago             2705988
# 240               Chicago             2705988
# ...                   ...                 ...
# 18480             Chicago             2705988
# 18720             Chicago             2705988
# 55860             Chicago             2705988
# 73620             Chicago             2705988
# 91860             Chicago             2705988
#
# [131 rows x 9 columns]

# %%
travel_counts_viz = plt.(travel_counts["Population - Total"], travel_counts["AVG_RIDES"])

# %%
y_values = yearly_transit["THEYEAR"]
x_values = yearly_transit["CTA_BUS"]
plt.scatter(yearly_transit["THEYEAR"], yearly_transit["CTA_BUS"])
plt.scatter(yearly_transit["THEYEAR"], yearly_transit["CTA_RAIL"])
plt.scatter(yearly_transit["THEYEAR"], yearly_transit["METRA"])
plt.show()

# %%
#cta_df = pd.merge(cta_bus_df, cta_rail_df, on="YEAR")

# %%
#cta_df
