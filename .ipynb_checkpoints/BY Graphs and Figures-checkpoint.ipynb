# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
import sklearn.datasets as dta
from sklearn import datasets
import requests
import os

# %%
Chicago_Building_Benchmark = "Data\\Chicago_Energy_Benchmarking.csv"
Chicago_Population = "Data\\Chicago_Population_Counts_2018.csv"
Energy_Usage = "Data\\Energy_Usage_2010.csv"
Illinois_Pop = "Data\\illinois_county_data.csv"

# %%
Chicago_Population
# Out:
# 'Data\\Chicago_Population_Counts_2018.csv'

# %%
building_benchmark_df = pd.read_csv(Chicago_Building_Benchmark)
chicago_pop_df = pd.read_csv(Chicago_Population)
energy_usage_df = pd.read_csv(Energy_Usage)
illinois_pop_df = pd.read_csv(Illinois_Pop)

# %%
energy_usage_df.fillna(0, inplace=True)
energy_usage_df.head()
# Out:
#   COMMUNITY AREA NAME  Neighboorhood Population  Neighborhood Area  Latitude  \
# 0         Albany Park                     51992               1.92  41.93179
# 1         Albany Park                     51992               1.92  41.93179
# 2         Albany Park                     51992               1.92  41.93179
# 3         Albany Park                     51992               1.92  41.93179
# 4         Albany Park                     51992               1.92  41.93179
#
#    Longitude  CENSUS BLOCK BUILDING TYPE BUILDING_SUBTYPE  KWH JANUARY 2010  \
# 0 -87.726979  1.700000e+14    Commercial        Multi < 7             626.0
# 1 -87.726979  0.000000e+00             0                0         2220671.0
# 2 -87.726979  1.700000e+14   Residential         Multi 7+           11921.0
# 3 -87.726979  1.700000e+14   Residential        Multi < 7            1233.0
# 4 -87.726979  1.700000e+14   Residential         Multi 7+               0.0
#
#    KWH FEBRUARY 2010  ...  TOTAL POPULATION  TOTAL UNITS  AVERAGE STORIES  \
# 0              632.0  ...              80.0         51.0             2.00
# 1          2109977.0  ...           20271.0       7713.0             1.65
# 2            12145.0  ...             132.0         64.0             3.00
# 3             1645.0  ...             132.0         64.0             2.00
# 4                0.0  ...              86.0         57.0             3.00
#
#    AVERAGE BUILDING AGE  AVERAGE HOUSESIZE  OCCUPIED UNITS  \
# 0                 85.00               1.78            45.0
# 1                 66.77             678.87          6822.0
# 2                 65.50               2.20            60.0
# 3                 86.00               2.20            60.0
# 4                 89.00               1.83            47.0
#
#    OCCUPIED UNITS PERCENTAGE  RENTER-OCCUPIED HOUSING UNITS  \
# 0                     0.8824                           19.0
# 1                     0.8845                         4535.0
# 2                     0.9375                           33.0
# 3                     0.9375                           33.0
# 4                     0.8245                           42.0
#
#    RENTER-OCCUPIED HOUSING PERCENTAGE  OCCUPIED HOUSING UNITS
# 0                              0.4220                    45.0
# 1                              0.6648                  6822.0
# 2                              0.5500                    60.0
# 3                              0.5500                    60.0
# 4                              0.8940                    47.0
#
# [5 rows x 77 columns]

# %%
energy_usage_df.count()
# Out:
# COMMUNITY AREA NAME                   67050
# Neighboorhood Population              67050
# Neighborhood Area                     67050
# Latitude                              67050
# Longitude                             67050
#                                       ...
# OCCUPIED UNITS                        67050
# OCCUPIED UNITS PERCENTAGE             67050
# RENTER-OCCUPIED HOUSING UNITS         67050
# RENTER-OCCUPIED HOUSING PERCENTAGE    67050
# OCCUPIED HOUSING UNITS                67050
# Length: 77, dtype: int64

# %%
winter_kwh = energy_usage_df['KWH JANUARY 2010'] + energy_usage_df['KWH FEBRUARY 2010'] + energy_usage_df['KWH DECEMBER 2010']
spring_kwh = energy_usage_df['KWH MARCH 2010'] + energy_usage_df['KWH APRIL 2010'] + energy_usage_df['KWH MAY 2010']
summer_kwh = energy_usage_df['KWH JUNE 2010'] + energy_usage_df['KWH JULY 2010'] + energy_usage_df['KWH AUGUST 2010']
fall_kwh = energy_usage_df['KWH SEPTEMBER 2010'] + energy_usage_df['KWH OCTOBER 2010'] + energy_usage_df['KWH NOVEMBER 2010']
energy_usage_df["spring_electricity"] = spring_kwh
energy_usage_df["winter_electricity"] = winter_kwh
energy_usage_df["summer_electricity"] = summer_kwh
energy_usage_df["fall_electricity"] = fall_kwh
winter_therm = energy_usage_df['THERM JANUARY 2010'] + energy_usage_df['THERM FEBRUARY 2010'] + energy_usage_df['THERM DECEMBER 2010']
spring_therm = energy_usage_df['THERM MARCH 2010'] + energy_usage_df['TERM APRIL 2010'] + energy_usage_df['THERM MAY 2010']
summer_therm = energy_usage_df['THERM JUNE 2010'] + energy_usage_df['THERM JULY 2010'] + energy_usage_df['THERM AUGUST 2010']
fall_therm = energy_usage_df['THERM SEPTEMBER 2010'] + energy_usage_df['THERM OCTOBER 2010'] + energy_usage_df['THERM NOVEMBER 2010']
energy_usage_df["spring_gas"] = spring_therm
energy_usage_df["winter_gas"] = winter_therm
energy_usage_df["summer_gas"] = summer_therm
energy_usage_df["fall_gas"] = fall_therm

# %%
energy_usage_df["winter_electricity"].sum()
# Out:
# 3894577950.0

# %%
np.warnings.filterwarnings('ignore')

# %%
#compare_df = energy_usage_df[(energy_usage_df["spring_electricity"] > 0) & (energy_usage_df["summer_electricity"] > 0) & (energy_usage_df["fall_electricity"] > 0) & (energy_usage_df["winter_electricity"] > 0) & (energy_usage_df["spring_gas"] > 0) & (energy_usage_df["summer_gas"] > 0) & (energy_usage_df["fall_gas"] > 0) & (energy_usage_df["winter_gas"] > 0)]

data = [energy_usage_df["spring_electricity"].mean(), energy_usage_df["summer_electricity"].mean(), energy_usage_df["fall_electricity"].mean(), energy_usage_df["winter_electricity"].mean()]
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
x_axis = seasons
plt.labels = seasons
plt.xlabel ="Season"
plt.ylabel = "Electricity Usage"
plt.bar(x_axis, data)
plt.title('Electricity Usage by Season Chicago 2010')

plt.show()
#compare_df["summer_electricity"].max()

# %%
data = [energy_usage_df["spring_gas"].mean(), energy_usage_df["summer_gas"].mean(), energy_usage_df["fall_gas"].mean(), energy_usage_df["winter_gas"].mean()]
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
x_axis = seasons
plt.labels = seasons
plt.xlabel ="Season"
plt.ylabel = "Gas Usage"
plt.bar(x_axis, data)
plt.title('Gas Usage by Season Chicago 2010')
# Out:
# Text(0.5, 1.0, 'Gas Usage by Season Chicago 2010')

# %%
chicago_pop_df.fillna("")
chicago_pop_df.head()
# Out:
#   Geography Type  Year  Geography COMMUNITY AREA NAME  Population - Total  \
# 0       Citywide  2018        NaN             Chicago             2705988
# 1       ZIP Code  2018    60601.0            The Loop               14675
# 2       ZIP Code  2018    60602.0            The Loop                1244
# 3       ZIP Code  2018    60603.0            The Loop                1174
# 4       ZIP Code  2018    60604.0            The Loop                 782
#
#     Latitude  Longitude
# 0        NaN        NaN
# 1  41.888836 -87.622714
# 2  41.884357 -87.609970
# 3  41.882112 -87.616335
# 4  41.879242 -87.633759

# %%
#neighborhood_energy_grouping = energy_usage_df.groupby(['COMMUNITY AREA NAME'])
#neighborhoods = pd.unique(compare_df["COMMUNITY AREA NAME"])

#len(neighborhoods)

# %%
neighborhood_df = energy_usage_df.loc[(energy_usage_df["BUILDING TYPE"] == "Residential") & (energy_usage_df["COMMUNITY AREA NAME"] != "Loop")]
neighborhood_group = neighborhood_df.groupby(['COMMUNITY AREA NAME'])
electricity_by_neighborhood = neighborhood_group['TOTAL KWH'].mean()
neighborhoods = neighborhood_df['COMMUNITY AREA NAME'].unique()
data = neighborhood_group['TOTAL KWH'].mean() / neighborhood_group['TOTAL POPULATION'].mean()
x_axis = neighborhoods
plt.labels = neighborhoods

plt.figure(figsize =(50, 15))
plt.xlabel ="Neighborhhods"
plt.ylabel = "Electricity Usage"
plt.bar(x_axis, data, align='center', width=0.75)
plt.title('Average Electricity Usage by Residents Chicago 2010')
plt.xticks(rotation=85, fontsize=30)
plt.yticks(fontsize=30)


plt.show()

# %%
import gmaps

# %%
neighborhood_df.head()
# Out:
#   COMMUNITY AREA NAME  Neighboorhood Population  Neighborhood Area  Latitude  \
# 2         Albany Park                     51992               1.92  41.93179
# 3         Albany Park                     51992               1.92  41.93179
# 4         Albany Park                     51992               1.92  41.93179
# 6         Albany Park                     51992               1.92  41.93179
# 7         Albany Park                     51992               1.92  41.93179
#
#    Longitude  CENSUS BLOCK BUILDING TYPE BUILDING_SUBTYPE  KWH JANUARY 2010  \
# 2 -87.726979  1.700000e+14   Residential         Multi 7+           11921.0
# 3 -87.726979  1.700000e+14   Residential        Multi < 7            1233.0
# 4 -87.726979  1.700000e+14   Residential         Multi 7+               0.0
# 6 -87.726979  1.700000e+14   Residential         Multi 7+            1230.0
# 7 -87.726979  1.700000e+14   Residential        Multi < 7           12977.0
#
#    KWH FEBRUARY 2010  ...  RENTER-OCCUPIED HOUSING PERCENTAGE  \
# 2            12145.0  ...                               0.550
# 3             1645.0  ...                               0.550
# 4                0.0  ...                               0.894
# 6             1333.0  ...                               0.754
# 7            14639.0  ...                               0.754
#
#    OCCUPIED HOUSING UNITS  spring_electricity  winter_electricity  \
# 2                    60.0             35649.0             46528.0
# 3                    60.0              3333.0              4500.0
# 4                    47.0                 0.0                 0.0
# 6                    65.0              4364.0              4058.0
# 7                    65.0             44075.0             58276.0
#
#    summer_electricity  fall_electricity  spring_gas  winter_gas  summer_gas  \
# 2             71210.0           47645.0     10115.0     18036.0      3458.0
# 3              9153.0            3622.0       154.0       529.0        30.0
# 4                 0.0               0.0      2884.0      6191.0      1083.0
# 6              4138.0            4192.0      2758.0      8526.0       996.0
# 7             81320.0           60670.0     15338.0     27732.0      3677.0
#
#    fall_gas
# 2    5213.0
# 3      42.0
# 4    1431.0
# 6    2373.0
# 7    4843.0
#
# [5 rows x 85 columns]

# %%
gmaps.configure(api_key="AIzaSyBnxBhLONnORL5jVjDkryq0_RPA72kghKY")


locations = neighborhood_df[["Latitude", "Longitude"]]

locations
# Out:
#         Latitude  Longitude
# 2      41.931790 -87.726979
# 3      41.931790 -87.726979
# 4      41.931790 -87.726979
# 6      41.931790 -87.726979
# 7      41.931790 -87.726979
# ...          ...        ...
# 67044  41.780229 -87.596261
# 67045  41.780229 -87.596261
# 67047  41.780229 -87.596261
# 67048  41.780229 -87.596261
# 67049  41.780229 -87.596261
#
# [49747 rows x 2 columns]

# %%
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
data = neighborhood_df['TOTAL KWH']
energy_heatmap = gmaps.heatmap_layer(locations, weights=data, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
commercial_df = energy_usage_df.loc[energy_usage_df["BUILDING TYPE"] == "Commercial"]
commercial_df_areas = commercial_df.groupby(['COMMUNITY AREA NAME'])
electricity_by_commercial = commercial_df['TOTAL KWH'].mean()
commercial = commercial_df['COMMUNITY AREA NAME'].unique()
data = commercial_df['TOTAL KWH'].mean()
locations_c = commercial_df[["Latitude", "Longitude"]]
locations_c
# Out:
#         Latitude  Longitude
# 0      41.931790 -87.726979
# 5      41.931790 -87.726979
# 8      41.931790 -87.726979
# 12     41.931790 -87.726979
# 13     41.931790 -87.726979
# ...          ...        ...
# 67036  41.780229 -87.596261
# 67038  41.780229 -87.596261
# 67041  41.780229 -87.596261
# 67043  41.780229 -87.596261
# 67046  41.780229 -87.596261
#
# [17185 rows x 2 columns]

# %%
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
data_c = commercial_df['TOTAL KWH']
energy_heatmap = gmaps.heatmap_layer(locations_c, weights=data_c, 
                                     dissipating=False, max_intensity=0.8, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
data_cg = commercial_df['TOTAL THERMS']
energy_heatmap = gmaps.heatmap_layer(locations_c, weights=data_cg, 
                                     dissipating=False, max_intensity=0.8, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
data_rg = neighborhood_df['TOTAL THERMS']
energy_heatmap = gmaps.heatmap_layer(locations, weights=data_rg, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
building_energy_grouping = compare_df.groupby('BUILDING TYPE')
#building_energy_grouping["fall_gas"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-655850a0b5cd> in <module>
# ----> 1 building_energy_grouping = compare_df.groupby('BUILDING TYPE')
#       2 #building_energy_grouping["fall_gas"].mean()
#
# NameError: name 'compare_df' is not defined

# %%
data = [building_energy_grouping["spring_gas"].mean(), building_energy_grouping["summer_gas"].mean(), building_energy_grouping["fall_gas"].mean(), building_energy_grouping["winter_gas"].mean()]
building_type = ['0', 'Commercial', 'Industrial', 'Residential']
x_axis = building_type
plt.labels = building_type
plt.xlabel ="Type"
plt.ylabel = "Gas Usage"
plt.bar(building_type, data)
plt.title('Gas Usage by Buliding Type Chicago 2010')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-14b93dea0827> in <module>
# ----> 1 data = [building_energy_grouping["spring_gas"].mean(), building_energy_grouping["summer_gas"].mean(), building_energy_grouping["fall_gas"].mean(), building_energy_grouping["winter_gas"].mean()]
#       2 building_type = ['0', 'Commercial', 'Industrial', 'Residential']
#       3 x_axis = building_type
#       4 plt.labels = building_type
#       5 plt.xlabel ="Type"
#
# NameError: name 'building_energy_grouping' is not defined

# %%
data = [Loop_df["spring_gas"].sum(), Loop_df["summer_gas"].sum(), Loop_df["fall_gas"].sum(), Loop_df["winter_gas"].sum()]
seasons = ['Spring', 'Summer', 'Fall', 'Winter']
x_axis = seasons
plt.labels = seasons
plt.xlabel ="Season"
plt.ylabel = "Gas Usage"
plt.bar(seasons, data)
plt.title('Gas Usage by The Loop Chicago 2010')

# %%
neighborhood_df_subtype = neighborhood_df.groupby("BUILDING_SUBTYPE")
neighborhood_df_subtype['TOTAL KWH', 'TOTAL THERMS'].sum()

# %%
commercial_df_subtype = commercial_df.groupby("COMMUNITY AREA NAME")
commercial_df_subtype['TOTAL KWH', 'TOTAL THERMS'].sum()
# Out:
#                        TOTAL KWH  TOTAL THERMS
# COMMUNITY AREA NAME
# Albany Park           36505163.0     4458603.0
# Archer Heights        72821203.0     2706704.0
# Armour Square         39882971.0     2494490.0
# Ashburn               29524013.0     1433976.0
# Auburn Gresham        19366766.0     2776755.0
# ...                          ...           ...
# West Lawn             88321877.0     3868470.0
# West Pullman           6111984.0      710444.0
# West Ridge            69316284.0     8276739.0
# West Town            130762381.0    10144676.0
# Woodlawn             125919238.0     2501807.0
#
# [77 rows x 2 columns]

# %%
loop_c_df = commercial_df.loc[commercial_df["COMMUNITY AREA NAME"] == "Loop"]

loop_c_df['TOTAL KWH'].sum() / commercial_df['TOTAL KWH'].sum()
# Out:
# 0.2453098449609235

# %%
loop_c_df['TOTAL THERMS'].sum() / commercial_df['TOTAL THERMS'].sum()
# Out:
# 0.09846210857864961

# %%
neighborhood_df['TOTAL THERMS'].sum() / energy_usage_df['TOTAL THERMS'].sum()
# Out:
# 0.5286589716067387

# %%
commercial_df['TOTAL THERMS'].sum() / energy_usage_df['TOTAL THERMS'].sum()
# Out:
# 0.29594857216097503

# %%
neighborhood_df['TOTAL KWH'].sum() / energy_usage_df['TOTAL KWH'].sum()
# Out:
# 0.2652386846177914

# %%
commercial_df['TOTAL KWH'].sum() / energy_usage_df['TOTAL KWH'].sum()
# Out:
# 0.459316554477588

# %%
commercial_df['TOTAL KWH'].sum() / commercial_df['TOTAL POPULATION'].sum()
# Out:
# 4280.992832764505

# %%
neighborhood_df['TOTAL KWH'].sum() / neighborhood_df['TOTAL POPULATION'].sum()
# Out:
# 1060.2534745442774

# %%
commercial_df['TOTAL KWH'].sum()
# Out:
# 7212402675.0

# %%
neighborhood_df['TOTAL KWH'].sum()
# Out:
# 4164901482.0

# %%
locations_te = energy_usage_df[["Latitude", "Longitude"]]
data_te = energy_usage_df['TOTAL KWH']
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
energy_heatmap = gmaps.heatmap_layer(locations_te, weights=data_te, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
locations_tg = energy_usage_df[["Latitude", "Longitude"]]
data_tg = energy_usage_df['TOTAL THERMS']
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
energy_heatmap = gmaps.heatmap_layer(locations_tg, weights=data_tg, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
data = [energy_usage_df['THERM JANUARY 2010'].mean(), energy_usage_df['THERM FEBRUARY 2010'].mean(), energy_usage_df['THERM MARCH 2010'].mean(), energy_usage_df['TERM APRIL 2010'].mean(), energy_usage_df['THERM MAY 2010'].mean(), energy_usage_df['THERM JUNE 2010'].mean(), energy_usage_df['THERM JULY 2010'].mean(), energy_usage_df['THERM AUGUST 2010'].mean(), energy_usage_df['THERM SEPTEMBER 2010'].mean(), energy_usage_df['THERM OCTOBER 2010'].mean(), energy_usage_df['THERM NOVEMBER 2010'].mean(), energy_usage_df['THERM DECEMBER 2010'].mean()]
x_axis = months
plt.labels = data

plt.figure(figsize =(30, 8))
plt.xlabel ="Months"
plt.ylabel = "Gas Usage"
plt.bar(x_axis, data, align='center', width=0.75)
plt.title('Average Gas Usage by Month Chicago 2010')
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)


plt.show()

# %%
neighborhood_grouping = neighborhood_df.groupby("COMMUNITY AREA NAME")
df = pd.DataFrame({'Population': neighborhood_grouping['Neighboorhood Population'].mean(), 'Number of Buildings': neighborhood_grouping['BUILDING TYPE'].count()})
df
# Out:
#                      Population  Number of Buildings
# COMMUNITY AREA NAME
# Albany Park               51992                  772
# Archer Heights            13142                  312
# Armour Square             13455                  178
# Ashburn                   43792                  766
# Auburn Gresham            46278                 1157
# ...                         ...                  ...
# West Lawn                 33108                  593
# West Pullman              27742                 1011
# West Ridge                76215                 1088
# West Town                 84502                 1779
# Woodlawn                  23268                  397
#
# [76 rows x 2 columns]

# %%
commercial_grouping = commercial_df.groupby("COMMUNITY AREA NAME")
df_c = pd.DataFrame({'Workforce Avg 2010': commercial_grouping['TOTAL POPULATION'].mean(), 'Commercial Buildings': commercial_grouping['BUILDING TYPE'].count(), 'Population Avg 2020': commercial_grouping['TOTAL POPULATION'].mean() * 0.3})
df_c
# Out:
#                      Workforce Avg 2010  Commercial Buildings  \
# COMMUNITY AREA NAME
# Albany Park                  117.031579                   380
# Archer Heights                35.098765                    81
# Armour Square                119.941176                   102
# Ashburn                       49.870000                   100
# Auburn Gresham                61.376866                   268
# ...                                 ...                   ...
# West Lawn                     51.818182                    99
# West Pullman                  48.115789                    95
# West Ridge                   118.415842                   505
# West Town                     80.208640                  1088
# Woodlawn                      95.756219                   201
#
#                      Population Avg 2020
# COMMUNITY AREA NAME
# Albany Park                    35.109474
# Archer Heights                 10.529630
# Armour Square                  35.982353
# Ashburn                        14.961000
# Auburn Gresham                 18.413060
# ...                                  ...
# West Lawn                      15.545455
# West Pullman                   14.434737
# West Ridge                     35.524752
# West Town                      24.062592
# Woodlawn                       28.726866
#
# [77 rows x 3 columns]

# %%
new_res_electricity = neighborhood_df['TOTAL KWH'] * 1.5
neighborhood_df['2020 KWH'] = new_res_electricity
new_comm_electricity = commercial_df['TOTAL KWH'] * 0.9
commercial_df['2020 KWH'] = new_comm_electricity

new_res_gas = neighborhood_df['TOTAL THERMS'] * 1.4
neighborhood_df['2020 THERMS'] = new_res_gas
new_comm_gas = commercial_df['TOTAL THERMS'] * 0.8
commercial_df['2020 THERMS'] = new_comm_gas

# %%
_total = pd.merge(neighborhood_df, commercial_df, how="outer")

# %%
_total.head()
# Out:
#   COMMUNITY AREA NAME  Neighboorhood Population  Neighborhood Area  Latitude  \
# 0         Albany Park                     51992               1.92  41.93179
# 1         Albany Park                     51992               1.92  41.93179
# 2         Albany Park                     51992               1.92  41.93179
# 3         Albany Park                     51992               1.92  41.93179
# 4         Albany Park                     51992               1.92  41.93179
#
#    Longitude  CENSUS BLOCK BUILDING TYPE BUILDING_SUBTYPE  KWH JANUARY 2010  \
# 0 -87.726979  1.700000e+14   Residential         Multi 7+           11921.0
# 1 -87.726979  1.700000e+14   Residential        Multi < 7            1233.0
# 2 -87.726979  1.700000e+14   Residential         Multi 7+               0.0
# 3 -87.726979  1.700000e+14   Residential         Multi 7+            1230.0
# 4 -87.726979  1.700000e+14   Residential        Multi < 7           12977.0
#
#    KWH FEBRUARY 2010  ...  spring_electricity  winter_electricity  \
# 0            12145.0  ...             35649.0             46528.0
# 1             1645.0  ...              3333.0              4500.0
# 2                0.0  ...                 0.0                 0.0
# 3             1333.0  ...              4364.0              4058.0
# 4            14639.0  ...             44075.0             58276.0
#
#    summer_electricity  fall_electricity  spring_gas  winter_gas  summer_gas  \
# 0             71210.0           47645.0     10115.0     18036.0      3458.0
# 1              9153.0            3622.0       154.0       529.0        30.0
# 2                 0.0               0.0      2884.0      6191.0      1083.0
# 3              4138.0            4192.0      2758.0      8526.0       996.0
# 4             81320.0           60670.0     15338.0     27732.0      3677.0
#
#    fall_gas  2020 KWH  2020 THERMS
# 0    5213.0  301548.0      51550.8
# 1      42.0   30912.0       1057.0
# 2    1431.0       0.0      16224.6
# 3    2373.0   25128.0      20514.2
# 4    4843.0  366511.5      72226.0
#
# [5 rows x 87 columns]

# %%
locations_twenty = _total[["Latitude", "Longitude"]]
data_twenty = _total['2020 KWH']
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
energy_heatmap = gmaps.heatmap_layer(locations_twenty, weights=data_twenty, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
neighborhood_df['TOTAL KWH'].sum()
# Out:
# 4161548220.0

# %%
commercial_df['TOTAL KWH'].sum()
# Out:
# 7212402675.0

# %%
neighborhood_df['TOTAL THERMS'].sum()
# Out:
# 694704850.0

# %%
commercial_df['TOTAL THERMS'].sum()
# Out:
# 389086051.0

# %%
_total.loc(_total['2020 KWH'] == 'Residential').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-c47c7aeefad4> in <module>
# ----> 1 _total.loc(_total['2020 KWH'] == 'Residential').sum()
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     576
#     577         if axis is not None:
# --> 578             axis = self.obj._get_axis_number(axis)
#     579         new_self.axis = axis
#     580         return new_self
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     396     @classmethod
#     397     def _get_axis_number(cls, axis):
# --> 398         axis = cls._AXIS_ALIASES.get(axis, axis)
#     399         if is_integer(axis):
#     400             if axis in cls._AXIS_NAMES:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1796
#    1797     def __hash__(self):
# -> 1798         raise TypeError(
#    1799             f"{repr(type(self).__name__)} objects are mutable, "
#    1800             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
locations_twenty = _total[["Latitude", "Longitude"]]
data_twenty = _total['2020 THERMS']
figure = gmaps.figure(center=(41.8650, -87.6073), zoom_level=10.85)
energy_heatmap = gmaps.heatmap_layer(locations_twenty, weights=data_twenty, 
                                     dissipating=False, max_intensity=0.7, 
                                     point_radius = 0.03)

figure.add_layer(energy_heatmap)

figure
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
commercial_TWENTY = _total.loc[_total["BUILDING TYPE"] == "Commercial"]
residential_TWENTY = _total.loc[_total["BUILDING TYPE"] == "Residential"]

# %%
residential_TWENTY['2020 KWH'].sum()
# Out:
# 6242322330.0

# %%
commercial_TWENTY['2020 KWH'].sum()
# Out:
# 6491162407.5

# %%
residential_TWENTY['2020 THERMS'].sum()
# Out:
# 972586789.9999999

# %%
commercial_TWENTY['2020 THERMS'].sum()
# Out:
# 311268840.8
